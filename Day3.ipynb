# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkrishx/python-data-analytics-/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Error handling

# %%
#error hanling

try:
  n = int(input("Enter a number:"))
  print(n)

except:
  print("Invalid input")
# Out:
# Enter a number:ak
# Invalid input

# %%
#practice: Attendence Calculator

def percentage(x,y):
  perc = (y/x)*100
  return round(perc,2 )

def status(percentage):
  if percentage >= 75:
    return "Eligible"
  else:
    return "Not eligible"

try:
  x = int(input("Total classes:"))
  y = int(input("classes attented:"))

  pct = percentage(x,y)
  st = status(pct)

  print("Percentage:",pct,"%")
  print("Status:",st)

except:
  print("Invalid input")
# Out:
# Total classes:11
# classes attented:6
# Percentage: 54.55 %
# Status: Not eligible

# %% [markdown]
# # Numpy

# %%
import numpy as np
arr = np.array([1,2,3,4,5]) #1D arr
print(arr)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np
arr = np.array([[1,2],[2,4]]) #2D arr
print(arr)
# Out:
# [[1 2]
#  [2 4]]

# %%
import numpy as np
arr = np.array([[[1,2],[2,4]],[[3,5],[6,7]]]) #3D arr
print(arr)
# Out:
# [[[1 2]
#   [2 4]]
#
#  [[3 5]
#   [6 7]]]

# %% [markdown]
# # Numpy array function

# %%
# zeros()

import numpy as np
arr = np.zeros([2,3])
print(arr)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
# ones()

import numpy as np
arr = np.ones([2,3])
print(arr)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
#arange()

import numpy as np
arr = np.arange(1,10)
print(arr)


arr2 = np.arange(1,10,2)
print(arr2)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [1 3 5 7 9]

# %%
# linspace() --> evenly spaced value

import numpy as np
arr = np.linspace(0,10,5)
print(arr)
# Out:
# [ 0.   2.5  5.   7.5 10. ]

# %%
#random.rand()

import numpy as np
arr = np.random.rand(3)
res = np.round(arr,2)
print(res)
# Out:
# [0.25 0.67 0.89]

# %%
#eye()  --> Identity Matrix

import numpy as np
arr = np.eye(3)
print(arr)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# # Array operation

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])

#addition
c = a+b
print(c)

#multiplication
d= a*b
print(d)

#power
e = a**2
print(e)

#sqrt
f = np.sqrt(a)
print(f)

#sum
g = np.sum(a)
print(g)
# Out:
# [5 7 9]
# [ 4 10 18]
# [1 4 9]
# [1.         1.41421356 1.73205081]
# 6
