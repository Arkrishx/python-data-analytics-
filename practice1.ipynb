# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkrishx/python-data-analytics-/blob/main/practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
m1= int(input("Enter M1:"))
m2= int(input("Enter M2:"))
m3= int(input("Enter M3:"))
m4= int(input("Enter M4:"))
m5= int(input("Enter M5:"))

marks= [m1,m2,m3,m4,m5]
total=sum(marks)
Avg= total/5

print("total:", total)
print("Average:", Avg)

if Avg>= 50:
  print("pass")
else:
  70
  print("Fail")
# Out:
# Enter M1:50
# Enter M2:60
# Enter M3:80
# Enter M4:90
# Enter M5:70
# total: 350
# Average: 70.0
# pass
