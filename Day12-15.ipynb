# %% [markdown]
# <a href="https://colab.research.google.com/github/Arkrishx/python-data-analytics-/blob/main/Day12-15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Resume buliding

# %%
#Interview tips

# %%
#LinkedIn concept

# %%
#Career Objectives
